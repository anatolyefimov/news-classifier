# %%
import pandas as pd
import re
import nltk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f52fbeeae333> in <module>()
#       2 import re
#       3 from nltk.stem.snowball import RussianStemmer, EnglishStemmer
# ----> 4 nltk.download('stopwords')
#
# NameError: name 'nltk' is not defined

# %%
data = pd.read_csv('news_train.txt', sep='\t', header=None, names=['theme', 'header', 'content'])
data
# Out:
#            theme                                             header  \
# 0          style                  Rolex наградит победителей регаты
# 1          sport  Матс Сундин стал советником тренера сборной Шв...
# 2          media    Брендом года по версии EFFIE впервые стал город
# 3      economics  Цена нефти WTI снизилась после публикации данн...
# 4      economics  Сбербанк распродаст другим банкирам миллиардны...
# 5      economics   Умер многолетний руководитель Toyota Эйдзи Тоёда
# 6        culture    Стинг выставит накопленное имущество на аукцион
# 7          sport  Бывший тренер «Ростова» рассказал о воспитании...
# 8          media        Новый вид профиля Facebook открыли для всех
# 9         forces  «Адмирал Кузнецов» и «Петр Великий» отправилис...
# 10         media  Россия предложит ООН способ защиты от интернет...
# 11         sport  СМИ сообщили о переговорах Игоря Денисова с «З...
# 12        forces        Германия откажется от закупки беспилотников
# ...

# %%
n = int(6e4)

total_words={}
for i in range(n):
    words = data['content'][i]
    words = words.lower()
    words = re.sub('[-., \( \) » «]', ' ', words)
    words = re.sub('[^а-яa-z\s]', '', words)
    words = re.sub('\s{2,}', ' ', words)
    words = re.sub('\s([а-яa-z]{,2}\s){,5}', ' ', words)
    words = words.split()
    for word in words:
        word = EnglishStemmer(word)
        if not word in total_words.keys():
            total_words[word] = 1
        else:
            total_words[word]+=1
total_words= sorted(total_words.items())
print(total_words, len(total_words))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/nltk/corpus/util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/data.py in find(resource_name, paths)
#     698     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 699     raise LookupError(resource_not_found)
#     700
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/Users/anatolij/nltk_data'
# ...

# %%
data['theme'][0]
# Out:
# 'style'
